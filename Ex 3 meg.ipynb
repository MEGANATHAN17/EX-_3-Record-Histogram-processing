# %% [markdown]
# ## EX 3 Record-Histogram-processing
# ## Name : YOGAMAHENDRAN G
# ## Reg : 212225040500

# %%
import cv2
import matplotlib.pyplot as plt 
Gray_image=cv2.imread("sec.jpg")
plt.imshow(Gray_image)
plt.show()
Color_image=cv2.imread("Qn4.jpg")
plt.imshow(Color_image)
plt.show()

# %%
hist = cv2.calcHist([Gray_image],[0],None,[256],[0,256])
plt.figure()
plt.title("Histogram")
plt.xlabel('gray_scale value')
plt.ylabel('pixel count')
plt.stem(hist)
plt.show()

# %%
hist1 = cv2.calcHist([Color_image],[0],None,[256],[0,256]) 
plt.figure()
plt.title("Histogram")
plt.xlabel('color_scale value') 
plt.ylabel('pixel count')
plt.stem(hist1)
plt.show()

# %%
equ1=cv2.equalizeHist(cv2.imread('Qn4.jpg',0)) 
equ=cv2.cvtColor(equ1,cv2.COLOR_BGR2RGB) 
plt.title("Equalised Image")
plt.axis("off")
plt.imshow(equ) 
plt.show()
